# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_excel('Data Model - Pizza Sales.xlsx')

# %%
df.columns
# Out:
# Index(['order_details_id', 'order_id', 'pizza_id', 'quantity', 'order_date',
#        'order_time', 'unit_price', 'total_price', 'pizza_size',
#        'pizza_category', 'pizza_ingredients', 'pizza_name'],
#       dtype='object')

# %%
df['order_dates'] = df['order_date'].dt.day_name()
df['order_dates']
g = df['order_dates'].value_counts()
h = list(g)
print(h)

df['order_dates'] = df['order_date'].dt.day_name()
i = df['order_dates'].unique()
j = list(i)
j
# Out:
# [8106, 7355, 7323, 6797, 6753, 6369, 5917]
# ['Thursday', 'Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday']

# %%
from cycler import cycler

cores = plt.get_cmap('Pastel2').colors
ciclo_cores = cycler('color', cores)
plt.rc('axes', prop_cycle=ciclo_cores)

barras = plt.bar(j, h)

plt.bar_label(barras, labels=h, color='green')
plt.xticks(rotation=90)
plt.xlabel('Datas', fontsize=12, color='green')
plt.ylabel('Frequency', fontsize=12, color='green')
plt.title('Datas', color='green')

plt.tick_params(axis='x', length=0)



for i, barra in enumerate (barras):
    if i != h.index(max(h)):
        barras[i].set_color(cores[1])
        barras[i].set_alpha(0.3)

plt.show()

# %%
tamanho_pizza = df['pizza_size'].value_counts()
tamanho_pizza
# Out:
# pizza_size
# L      18526
# M      15385
# S      14137
# XL       544
# XXL       28
# Name: count, dtype: int64

# %%
destaques = [0.2, 0.0, 0.0, 0.0, 0.2]

plt.pie(tamanho_pizza, labels=tamanho_pizza.index, autopct='%1.2f%%', explode=destaques, startangle=140)

plt.title('Popularidade (%) dos tamanhos de\npizzas', fontsize=15)

plt.show()

print('Tamanho de pizza mais vendida: ', tamanho_pizza.index[0])
# Out:
# Tamanho de pizza mais vendida:  L
